# %% [markdown]
# <a href="https://colab.research.google.com/github/tpedCode/P07/blob/initialisation/1_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Implémentez un modèle de scoring**
#
# ### Objectif :
# - prédire la probabilité de défaut d’un client
# - optimiser un seuil métier (coût FN > FP)
# - préparer un modèle pour une API

# %%
import pandas as pd
import numpy as np

# %%
print("test sync colab -> github")
# Out:
# test sync colab -> github
