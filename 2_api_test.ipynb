# %% [markdown]
# <a href="https://colab.research.google.com/github/tpedCode/P07/blob/feat%2Fapi/2_api_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib
import pandas as pd
